# %%
import os
from dotenv import load_dotenv
from src.api_clients.news import get_news

load_dotenv()

news = get_news("Portugal", os.getenv("NEWS_API_KEY"))
print(news[:2])
# Out:
# [{'title': 'Suuure, 6-time WSBK champ Jonathan Rea Is Retired…', 'source': 'Rideapart.com', 'url': 'https://www.rideapart.com/news/791007/jonathan-rea-returns-worldsbk-honda-2026/', 'published_at': '2026-03-27T13:34:27Z'}, {'title': 'Rumor Mongering: Francisco Conceição Asked About Liverpool Links', 'source': 'SB Nation', 'url': 'https://liverpooloffside.sbnation.com/liverpool-fc-transfer-news/79438/rumor-mongering-francisco-conceicao-asked-about-liverpool-links', 'published_at': '2026-03-27T13:10:10Z'}]
