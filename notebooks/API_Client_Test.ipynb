# %%
from src.api_clients.countries import get_country_by_name
print(get_country_by_name("Portugal"))
# Out:
# {'name': 'Portugal', 'official_name': 'Portuguese Republic', 'capital': 'Lisbon', 'region': 'Europe', 'subregion': 'Southern Europe', 'population': 10749635, 'flag': 'https://flagcdn.com/w320/pt.png', 'languages': ['Portuguese'], 'currencies': ['EUR']}
