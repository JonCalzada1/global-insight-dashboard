# %%
from src.api_clients.weather import geocode_location, get_current_weather

location = geocode_location("Lisbon")
print(location)

weather = get_current_weather(location["latitude"], location["longitude"])
print(weather)
# Out:
# {'name': 'Lisbon', 'country': 'Portugal', 'latitude': 38.71667, 'longitude': -9.13333}
# {'temperature': 20.8, 'wind_speed': 17.1, 'weather_code': 0, 'time': '2026-03-28T13:15'}
